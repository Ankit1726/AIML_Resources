# %%
## Ques_1
name = input('enter your name')
age = int(input('enter your age'))
print(f"Hello {name}, you are {age} old..!")
# Out:
# Hello Ankit, you are 21 old..!

# %%
## Ques_2
n1 = int(input('enter your number'))
n2 = int(input('enter your number'))
print(f"Sum:{n1+n2}")
print(f"Difference:{n1-n2}")
print(f"Product:{n1*n2}")
print(f"Quotient:{n1%n2}")
# Out:
# Sum:145
# Difference:33
# Product:4984
# Quotient:33

# %%
### Ques_3
a = int(input('enter your number'))
b = int(input('enter your number'))
c = float(input('enter your number'))
a = float(a)
b = float(b)

avg = a+b+c/3
print(f"Average:{a+b+c}")
# Out:
# Average:144.9

# %%
## Ques_4
num = input('enter your number')
a = int(a)
print(a,type(a))
b = float(b)
print(b,type(b))
c = str(c)
print(c,type(c))
# Out:
# 45 <class 'int'>
# 21.0 <class 'float'>
# 78.9 <class 'str'>

# %%
## Ques_5
x = 10+3*2**3
print(x)
# Out:
# 34

# %%
## Ques_6
x = input('enter your number')
y = input('enter your number')
print(f"x:{x},y:{y}")
## swap 2 number
x,y = y,x
print(f"x:{x},y:{y}")
# Out:
# x:34,y:56
# x:56,y:34

# %%
## Ques_7
celcius = float(input('enter your temperature in Deg C'))
Fahrenhite_Temp = (celcius*(9/5)) + 32
print(f"Temperature in {Fahrenhite_Temp}F")
# Out:
# Temperature in 109.4F

# %%
## Ques_8
import math
r = int(input('enter your radius'))
Area = math.pi*r*r
print(f"Area of Circle: {Area}")
# Out:
# Area of Circle: 24884.555409084755

# %%
## Ques_9
P = float(input('enter your Principal Amount'))
R = float(input('enter your Rate in %'))
T = float(input('enter your Time in Yr'))

SI = (P*R*T)/100
print(f"Simple Interest: {SI}")
# Out:
# Simple Interest: 2136.0

# %%
## Ques_10
num = float(input("enter number in decimal"))
integer = int(num)
fraction = num - integer

print("Integer part:", integer)
print("Fractional part:", fraction)
# Out:
# Integer part: 45
# Fractional part: 0.6700000000000017
