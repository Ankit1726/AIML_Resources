# %% [markdown]
# ### Python Fundamantals Day_1
#
# - Variables: It is a Like container that stores data or values in our program.

# %%
name = "Python"
domain = "AIML"
print(name,domain)
# Out:
# Python AIML

# %% [markdown]
# - Naming Convention
#    - It start with a letter(a–z,A–Z) or underscore _.
#    - A letters,numbers,or underscores after the first character.
#    - It can not use Python Keyword like (for,while) etc.

# %%
## Data Types: It defines kind of value a variable can hold.

x = 10
print(type(x))

pi = 3.14
print(type(pi))

name = 'ankit'
print(type(name))

Engineer = True
print(type(Engineer))

empty_var = None
print(type(empty_var))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'NoneType'>

# %% [markdown]
# #### Operators: Symbols that perform a specific computation.
# - Arithmetic Operators
# - Relational Operators
# - Assignment Operators
# - Logical Operators

# %%
## Unary Operators: Works on Single Operand.
x= 5
y = -x
print(x)
print(y)
# Out:
# 5
# -5

# %%
## input(): It used to take user input.
name = input('enter your name: ')
print('Good Morning..!',name)
# Out:
# Good Morning..! Ankit

# %%
## Adding 2 Number From User Input
a = int(input('enter your number'))
b = int(input('enter your number'))

sum = a+b
print('sum of 2 numbers:',sum)
# Out:
# sum of 2 numbers: 123
