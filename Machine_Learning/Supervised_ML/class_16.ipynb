# %% [markdown]
# #### ML Fundamentals Day_46
# ***
# - Random Forest For Classification

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in d:\aiml prime\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in d:\aiml prime\.venv\lib\site-packages (from seaborn) (2.4.1)
# Requirement already satisfied: pandas>=1.2 in d:\aiml prime\.venv\lib\site-packages (from seaborn) (3.0.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in d:\aiml prime\.venv\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in d:\aiml prime\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\aiml prime\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\aiml prime\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\aiml prime\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\aiml prime\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in d:\aiml prime\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in d:\aiml prime\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\aiml prime\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in d:\aiml prime\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in d:\aiml prime\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    str
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    str
#  8   class        891 non-null    category
#  9   who          891 non-null    str
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    str
#  13  alive        891 non-null    str
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), str(5)
# memory usage: 80.7 KB

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
features = ["pclass","sex","fare","embarked","age"]
target = ["survived"]

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
## filling missing values
from sklearn.impute import SimpleImputer

## Numerical data
imp_median = SimpleImputer(strategy="median")
titanic[["age"]] = imp_median.fit_transform(titanic[["age"]])

## Categorical data
imp_freq = SimpleImputer(strategy="most_frequent")
titanic[["embarked"]] = imp_freq.fit_transform(titanic[["embarked"]])

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic.shape
# Out:
# (891, 15)

# %%
## encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

titanic["sex"] = le.fit_transform(titanic["sex"])
titanic["embarked"] = le.fit_transform(titanic["embarked"])

# %%
titanic.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  class    who  \
# 0         0       3    1  22.0      1      0   7.2500         2  Third    man
# 1         1       1    0  38.0      1      0  71.2833         0  First  woman
# 2         1       3    0  26.0      0      0   7.9250         2  Third  woman
# 3         1       1    0  35.0      1      0  53.1000         2  First  woman
# 4         0       3    1  35.0      0      0   8.0500         2  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %%
X = titanic[features]
Y = titanic[target]

# %%
X_train,X_test,Y_train,Y_test = train_test_split(
     X,Y,test_size=0.3,random_state=42
     )

# %%
X_train.head()
# Out:
#      pclass  sex     fare  embarked   age
# 445       1    1  81.8583         2   4.0
# 650       3    1   7.8958         2  28.0
# 172       3    0  11.1333         2   1.0
# 450       2    1  27.7500         2  36.0
# 314       2    1  26.2500         2  43.0

# %%
X_test.head()
# Out:
#      pclass  sex     fare  embarked   age
# 709       3    1  15.2458         0  28.0
# 439       2    1  10.5000         2  31.0
# 840       3    1   7.9250         2  20.0
# 720       2    0  33.0000         2   6.0
# 39        3    0  11.2417         0  14.0

# %%
## Decision Tree Model (no pruning)
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import accuracy_score
y_pred_test = model.predict(X_test)
y_pred_train = model.predict(X_train)

## Evaluation
print("Training Accuracy:",accuracy_score(Y_train,y_pred_train)*100,"%")
print("Testing Accuracy:",accuracy_score(Y_test,y_pred_test)*100,"%")
# Out:
# Training Accuracy: 97.91332263242376 %
# Testing Accuracy: 75.3731343283582 %

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(18,10))
plot_tree(
     model,
     feature_names=X.columns,
     class_names = ["Died","Survived"],
     filled=True,
)
# Out:
# [Text(0.31199971183401637, 0.9772727272727273, 'sex <= 0.5\ngini = 0.467\nsamples = 623\nvalue = [392, 231]\nclass = Died'),
#  Text(0.12986680327868852, 0.9318181818181818, 'pclass <= 2.5\ngini = 0.396\nsamples = 213\nvalue = [58, 155]\nclass = Survived'),
#  Text(0.22093325755635246, 0.9545454545454546, 'True  '),
#  Text(0.0389344262295082, 0.8863636363636364, 'age <= 2.5\ngini = 0.07\nsamples = 110\nvalue = [4, 106]\nclass = Survived'),
#  Text(0.01639344262295082, 0.8409090909090909, 'fare <= 88.775\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.00819672131147541, 0.7954545454545454, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.02459016393442623, 0.7954545454545454, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.06147540983606557, 0.8409090909090909, 'fare <= 149.035\ngini = 0.054\nsamples = 108\nvalue = [3, 105]\nclass = Survived'),
#  Text(0.040983606557377046, 0.7954545454545454, 'age <= 49.5\ngini = 0.041\nsamples = 96\nvalue = [2, 94]\nclass = Survived'),
#  Text(0.02459016393442623, 0.75, 'fare <= 22.0\ngini = 0.024\nsamples = 84\nvalue = [1, 83]\nclass = Survived'),
#  Text(0.01639344262295082, 0.7045454545454546, 'fare <= 20.25\ngini = 0.083\nsamples = 23\nvalue = [1, 22]\nclass = Survived'),
#  Text(0.00819672131147541, 0.6590909090909091, 'gini = 0.0\nsamples = 21\nvalue = [0, 21]\nclass = Survived'),
#  Text(0.02459016393442623, 0.6590909090909091, 'age <= 28.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.01639344262295082, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.03278688524590164, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.03278688524590164, 0.7045454545454546, 'gini = 0.0\nsamples = 61\nvalue = [0, 61]\nclass = Survived'),
#  Text(0.05737704918032787, 0.75, 'age <= 51.5\ngini = 0.153\nsamples = 12\nvalue = [1, 11]\nclass = Survived'),
#  Text(0.04918032786885246, 0.7045454545454546, 'fare <= 19.606\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.040983606557377046, 0.6590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.05737704918032787, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.06557377049180328, 0.7045454545454546, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = Survived'),
#  Text(0.08196721311475409, 0.7954545454545454, 'fare <= 152.506\ngini = 0.153\nsamples = 12\nvalue = [1, 11]\nclass = Survived'),
#  Text(0.07377049180327869, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.09016393442622951, 0.75, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = Survived'),
#  Text(0.22079918032786885, 0.8863636363636364, 'fare <= 23.35\ngini = 0.499\nsamples = 103\nvalue = [54, 49]\nclass = Died'),
#  Text(0.17930327868852458, 0.8409090909090909, 'age <= 36.5\ngini = 0.492\nsamples = 85\nvalue = [37, 48]\nclass = Survived'),
#  Text(0.1711065573770492, 0.7954545454545454, 'fare <= 15.373\ngini = 0.483\nsamples = 81\nvalue = [33, 48]\nclass = Survived'),
#  Text(0.11270491803278689, 0.75, 'fare <= 7.763\ngini = 0.499\nsamples = 57\nvalue = [27, 30]\nclass = Survived'),
#  Text(0.08196721311475409, 0.7045454545454546, 'fare <= 6.987\ngini = 0.363\nsamples = 21\nvalue = [5, 16]\nclass = Survived'),
#  Text(0.07377049180327869, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.09016393442622951, 0.6590909090909091, 'fare <= 7.59\ngini = 0.32\nsamples = 20\nvalue = [4, 16]\nclass = Survived'),
#  Text(0.08196721311475409, 0.6136363636363636, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Survived'),
#  Text(0.09836065573770492, 0.6136363636363636, 'fare <= 7.64\ngini = 0.408\nsamples = 14\nvalue = [4, 10]\nclass = Survived'),
#  Text(0.09016393442622951, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.10655737704918032, 0.5681818181818182, 'fare <= 7.744\ngini = 0.355\nsamples = 13\nvalue = [3, 10]\nclass = Survived'),
#  Text(0.09836065573770492, 0.5227272727272727, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Survived'),
#  Text(0.11475409836065574, 0.5227272727272727, 'age <= 21.5\ngini = 0.444\nsamples = 9\nvalue = [3, 6]\nclass = Survived'),
#  Text(0.10655737704918032, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.12295081967213115, 0.4772727272727273, 'age <= 25.0\ngini = 0.375\nsamples = 8\nvalue = [2, 6]\nclass = Survived'),
#  Text(0.11475409836065574, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.13114754098360656, 0.4318181818181818, 'gini = 0.408\nsamples = 7\nvalue = [2, 5]\nclass = Survived'),
#  Text(0.14344262295081966, 0.7045454545454546, 'age <= 9.0\ngini = 0.475\nsamples = 36\nvalue = [22, 14]\nclass = Died'),
#  Text(0.12295081967213115, 0.6590909090909091, 'fare <= 10.798\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Survived'),
#  Text(0.11475409836065574, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.13114754098360656, 0.6136363636363636, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Survived'),
#  Text(0.16393442622950818, 0.6590909090909091, 'age <= 25.5\ngini = 0.451\nsamples = 32\nvalue = [21, 11]\nclass = Died'),
#  Text(0.14754098360655737, 0.6136363636363636, 'age <= 19.0\ngini = 0.305\nsamples = 16\nvalue = [13, 3]\nclass = Died'),
#  Text(0.13934426229508196, 0.5681818181818182, 'embarked <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]\nclass = Died'),
#  Text(0.13114754098360656, 0.5227272727272727, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.14754098360655737, 0.5227272727272727, 'fare <= 7.89\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Survived'),
#  Text(0.13934426229508196, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.1557377049180328, 0.4772727272727273, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Survived'),
#  Text(0.1557377049180328, 0.5681818181818182, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = Died'),
#  Text(0.18032786885245902, 0.6136363636363636, 'age <= 27.5\ngini = 0.5\nsamples = 16\nvalue = [8, 8]\nclass = Died'),
#  Text(0.1721311475409836, 0.5681818181818182, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Survived'),
#  Text(0.1885245901639344, 0.5681818181818182, 'fare <= 7.888\ngini = 0.444\nsamples = 12\nvalue = [8, 4]\nclass = Died'),
#  Text(0.18032786885245902, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.19672131147540983, 0.5227272727272727, 'age <= 28.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]\nclass = Died'),
#  Text(0.1885245901639344, 0.4772727272727273, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Died'),
#  Text(0.20491803278688525, 0.4772727272727273, 'age <= 30.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.19672131147540983, 0.4318181818181818, 'fare <= 12.854\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.1885245901639344, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.20491803278688525, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.21311475409836064, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.22950819672131148, 0.75, 'embarked <= 1.5\ngini = 0.375\nsamples = 24\nvalue = [6, 18]\nclass = Survived'),
#  Text(0.22131147540983606, 0.7045454545454546, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = Survived'),
#  Text(0.23770491803278687, 0.7045454545454546, 'fare <= 17.7\ngini = 0.48\nsamples = 15\nvalue = [6, 9]\nclass = Survived'),
#  Text(0.22131147540983606, 0.6590909090909091, 'age <= 27.0\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = Survived'),
#  Text(0.21311475409836064, 0.6136363636363636, 'age <= 25.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.20491803278688525, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.22131147540983606, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.22950819672131148, 0.6136363636363636, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Survived'),
#  Text(0.2540983606557377, 0.6590909090909091, 'fare <= 21.55\ngini = 0.469\nsamples = 8\nvalue = [5, 3]\nclass = Died'),
#  Text(0.2459016393442623, 0.6136363636363636, 'age <= 30.0\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = Died'),
#  Text(0.23770491803278687, 0.5681818181818182, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Died'),
#  Text(0.2540983606557377, 0.5681818181818182, 'fare <= 19.125\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.2459016393442623, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.26229508196721313, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.26229508196721313, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.1875, 0.7954545454545454, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Died'),
#  Text(0.26229508196721313, 0.8409090909090909, 'age <= 7.0\ngini = 0.105\nsamples = 18\nvalue = [17, 1]\nclass = Died'),
#  Text(0.2540983606557377, 0.7954545454545454, 'age <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.2459016393442623, 0.75, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.26229508196721313, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.27049180327868855, 0.7954545454545454, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]\nclass = Died'),
#  Text(0.49413262038934425, 0.9318181818181818, 'age <= 6.5\ngini = 0.302\nsamples = 410\nvalue = [334, 76]\nclass = Died'),
#  Text(0.40306616611168034, 0.9545454545454546, '  False'),
#  Text(0.28688524590163933, 0.8863636363636364, 'fare <= 27.562\ngini = 0.42\nsamples = 20\nvalue = [6, 14]\nclass = Survived'),
#  Text(0.2786885245901639, 0.8409090909090909, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = Survived'),
#  Text(0.29508196721311475, 0.8409090909090909, 'pclass <= 2.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4]\nclass = Died'),
#  Text(0.28688524590163933, 0.7954545454545454, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Survived'),
#  Text(0.30327868852459017, 0.7954545454545454, 'age <= 2.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = Died'),
#  Text(0.29508196721311475, 0.75, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Died'),
#  Text(0.3114754098360656, 0.75, 'age <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.30327868852459017, 0.7045454545454546, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.319672131147541, 0.7045454545454546, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.7013799948770492, 0.8863636363636364, 'fare <= 52.277\ngini = 0.267\nsamples = 390\nvalue = [328.0, 62.0]\nclass = Died'),
#  Text(0.48267802254098363, 0.8409090909090909, 'age <= 77.0\ngini = 0.227\nsamples = 344\nvalue = [299, 45]\nclass = Died'),
#  Text(0.4744813012295082, 0.7954545454545454, 'pclass <= 1.5\ngini = 0.224\nsamples = 343\nvalue = [299, 44]\nclass = Died'),
#  Text(0.3524590163934426, 0.75, 'fare <= 30.75\ngini = 0.357\nsamples = 43\nvalue = [33, 10]\nclass = Died'),
#  Text(0.3360655737704918, 0.7045454545454546, 'fare <= 26.144\ngini = 0.444\nsamples = 27\nvalue = [18, 9]\nclass = Died'),
#  Text(0.32786885245901637, 0.6590909090909091, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Died'),
#  Text(0.3442622950819672, 0.6590909090909091, 'age <= 53.0\ngini = 0.49\nsamples = 21\nvalue = [12, 9]\nclass = Died'),
#  Text(0.3360655737704918, 0.6136363636363636, 'age <= 39.5\ngini = 0.48\nsamples = 15\nvalue = [6, 9]\nclass = Survived'),
#  Text(0.32786885245901637, 0.5681818181818182, 'fare <= 30.25\ngini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = Died'),
#  Text(0.319672131147541, 0.5227272727272727, 'fare <= 26.419\ngini = 0.444\nsamples = 9\nvalue = [6, 3]\nclass = Died'),
#  Text(0.3114754098360656, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.32786885245901637, 0.4772727272727273, 'fare <= 28.725\ngini = 0.375\nsamples = 8\nvalue = [6, 2]\nclass = Died'),
#  Text(0.319672131147541, 0.4318181818181818, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Died'),
#  Text(0.3360655737704918, 0.4318181818181818, 'age <= 28.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Died'),
#  Text(0.32786885245901637, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.3442622950819672, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.3360655737704918, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.3442622950819672, 0.5681818181818182, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Survived'),
#  Text(0.3524590163934426, 0.6136363636363636, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Died'),
#  Text(0.36885245901639346, 0.7045454545454546, 'age <= 55.0\ngini = 0.117\nsamples = 16\nvalue = [15, 1]\nclass = Died'),
#  Text(0.36065573770491804, 0.6590909090909091, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = Died'),
#  Text(0.3770491803278688, 0.6590909090909091, 'embarked <= 1.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.36885245901639346, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.38524590163934425, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.5965035860655737, 0.75, 'age <= 13.0\ngini = 0.201\nsamples = 300\nvalue = [266, 34]\nclass = Died'),
#  Text(0.46260245901639346, 0.7045454545454546, 'fare <= 17.344\ngini = 0.42\nsamples = 10\nvalue = [7, 3]\nclass = Died'),
#  Text(0.45440573770491804, 0.6590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.4707991803278688, 0.6590909090909091, 'pclass <= 2.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = Died'),
#  Text(0.46260245901639346, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.47899590163934425, 0.6136363636363636, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Died'),
#  Text(0.7304047131147541, 0.7045454545454546, 'age <= 32.25\ngini = 0.191\nsamples = 290\nvalue = [259, 31]\nclass = Died'),
#  Text(0.6247438524590164, 0.6590909090909091, 'age <= 31.5\ngini = 0.217\nsamples = 210\nvalue = [184, 26]\nclass = Died'),
#  Text(0.4953893442622951, 0.6136363636363636, 'embarked <= 0.5\ngini = 0.195\nsamples = 201\nvalue = [179, 22]\nclass = Died'),
#  Text(0.38729508196721313, 0.5681818181818182, 'age <= 22.5\ngini = 0.337\nsamples = 28\nvalue = [22, 6]\nclass = Died'),
#  Text(0.3524590163934426, 0.5227272727272727, 'age <= 17.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Died'),
#  Text(0.3442622950819672, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.36065573770491804, 0.4772727272727273, 'fare <= 5.619\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.3524590163934426, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.36885245901639346, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.42213114754098363, 0.5227272727272727, 'fare <= 7.562\ngini = 0.278\nsamples = 24\nvalue = [20, 4]\nclass = Died'),
#  Text(0.39344262295081966, 0.4772727272727273, 'fare <= 7.227\ngini = 0.153\nsamples = 12\nvalue = [11, 1]\nclass = Died'),
#  Text(0.38524590163934425, 0.4318181818181818, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Died'),
#  Text(0.4016393442622951, 0.4318181818181818, 'age <= 28.25\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = Died'),
#  Text(0.39344262295081966, 0.38636363636363635, 'gini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Died'),
#  Text(0.4098360655737705, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.45081967213114754, 0.4772727272727273, 'fare <= 14.158\ngini = 0.375\nsamples = 12\nvalue = [9, 3]\nclass = Died'),
#  Text(0.4344262295081967, 0.4318181818181818, 'pclass <= 2.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Died'),
#  Text(0.4262295081967213, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.4426229508196721, 0.38636363636363635, 'age <= 28.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.4344262295081967, 0.3409090909090909, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.45081967213114754, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.4672131147540984, 0.4318181818181818, 'pclass <= 2.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = Died'),
#  Text(0.45901639344262296, 0.38636363636363635, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Died'),
#  Text(0.47540983606557374, 0.38636363636363635, 'age <= 27.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.4672131147540984, 0.3409090909090909, 'fare <= 16.621\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.45901639344262296, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.47540983606557374, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.48360655737704916, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.6034836065573771, 0.5681818181818182, 'fare <= 7.798\ngini = 0.168\nsamples = 173\nvalue = [157, 16]\nclass = Died'),
#  Text(0.5245901639344263, 0.5227272727272727, 'fare <= 7.746\ngini = 0.278\nsamples = 48\nvalue = [40, 8]\nclass = Died'),
#  Text(0.5081967213114754, 0.4772727272727273, 'age <= 26.5\ngini = 0.147\nsamples = 25\nvalue = [23, 2]\nclass = Died'),
#  Text(0.5, 0.4318181818181818, 'fare <= 3.248\ngini = 0.245\nsamples = 14\nvalue = [12, 2]\nclass = Died'),
#  Text(0.4918032786885246, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.5081967213114754, 0.38636363636363635, 'age <= 23.0\ngini = 0.142\nsamples = 13\nvalue = [12, 1]\nclass = Died'),
#  Text(0.5, 0.3409090909090909, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = Died'),
#  Text(0.5163934426229508, 0.3409090909090909, 'age <= 24.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Died'),
#  Text(0.5081967213114754, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.5245901639344263, 0.29545454545454547, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.5163934426229508, 0.4318181818181818, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = Died'),
#  Text(0.5409836065573771, 0.4772727272727273, 'age <= 20.0\ngini = 0.386\nsamples = 23\nvalue = [17, 6]\nclass = Died'),
#  Text(0.5327868852459017, 0.4318181818181818, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Died'),
#  Text(0.5491803278688525, 0.4318181818181818, 'age <= 21.5\ngini = 0.432\nsamples = 19\nvalue = [13, 6]\nclass = Died'),
#  Text(0.5409836065573771, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.5573770491803278, 0.38636363636363635, 'age <= 24.5\ngini = 0.401\nsamples = 18\nvalue = [13, 5]\nclass = Died'),
#  Text(0.5491803278688525, 0.3409090909090909, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.5655737704918032, 0.3409090909090909, 'age <= 25.5\ngini = 0.43\nsamples = 16\nvalue = [11, 5]\nclass = Died'),
#  Text(0.5573770491803278, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.5737704918032787, 0.29545454545454547, 'age <= 30.0\ngini = 0.391\nsamples = 15\nvalue = [11, 4]\nclass = Died'),
#  Text(0.5655737704918032, 0.25, 'age <= 28.5\ngini = 0.426\nsamples = 13\nvalue = [9, 4]\nclass = Died'),
#  Text(0.5573770491803278, 0.20454545454545456, 'embarked <= 1.5\ngini = 0.375\nsamples = 12\nvalue = [9, 3]\nclass = Died'),
#  Text(0.5491803278688525, 0.1590909090909091, 'gini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = Died'),
#  Text(0.5655737704918032, 0.1590909090909091, 'age <= 26.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Died'),
#  Text(0.5573770491803278, 0.11363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.5737704918032787, 0.11363636363636363, 'age <= 27.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Died'),
#  Text(0.5655737704918032, 0.06818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.5819672131147541, 0.06818181818181818, 'fare <= 7.785\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.5737704918032787, 0.022727272727272728, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.5901639344262295, 0.022727272727272728, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.5737704918032787, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.5819672131147541, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.6823770491803278, 0.5227272727272727, 'age <= 30.5\ngini = 0.12\nsamples = 125\nvalue = [117, 8]\nclass = Died'),
#  Text(0.6516393442622951, 0.4772727272727273, 'age <= 20.5\ngini = 0.107\nsamples = 123\nvalue = [116, 7]\nclass = Died'),
#  Text(0.6147540983606558, 0.4318181818181818, 'fare <= 8.175\ngini = 0.219\nsamples = 32\nvalue = [28, 4]\nclass = Died'),
#  Text(0.5901639344262295, 0.38636363636363635, 'fare <= 7.91\ngini = 0.397\nsamples = 11\nvalue = [8, 3]\nclass = Died'),
#  Text(0.5819672131147541, 0.3409090909090909, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Died'),
#  Text(0.5983606557377049, 0.3409090909090909, 'fare <= 7.988\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = Died'),
#  Text(0.5901639344262295, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.6065573770491803, 0.29545454545454547, 'age <= 19.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Died'),
#  Text(0.5983606557377049, 0.25, 'age <= 17.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Died'),
#  Text(0.5901639344262295, 0.20454545454545456, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.6065573770491803, 0.20454545454545456, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.6147540983606558, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.639344262295082, 0.38636363636363635, 'age <= 18.5\ngini = 0.091\nsamples = 21\nvalue = [20, 1]\nclass = Died'),
#  Text(0.6311475409836066, 0.3409090909090909, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = Died'),
#  Text(0.6475409836065574, 0.3409090909090909, 'pclass <= 2.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = Died'),
#  Text(0.639344262295082, 0.29545454545454547, 'fare <= 11.75\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Died'),
#  Text(0.6311475409836066, 0.25, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.6475409836065574, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.6557377049180327, 0.29545454545454547, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Died'),
#  Text(0.6885245901639344, 0.4318181818181818, 'embarked <= 1.5\ngini = 0.064\nsamples = 91\nvalue = [88, 3]\nclass = Died'),
#  Text(0.6721311475409836, 0.38636363636363635, 'fare <= 19.375\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = Died'),
#  Text(0.6639344262295082, 0.3409090909090909, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Died'),
#  Text(0.680327868852459, 0.3409090909090909, 'fare <= 23.7\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.6721311475409836, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.6885245901639344, 0.29545454545454547, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.7049180327868853, 0.38636363636363635, 'fare <= 8.081\ngini = 0.046\nsamples = 84\nvalue = [82, 2]\nclass = Died'),
#  Text(0.6967213114754098, 0.3409090909090909, 'gini = 0.0\nsamples = 39\nvalue = [39, 0]\nclass = Died'),
#  Text(0.7131147540983607, 0.3409090909090909, 'fare <= 8.388\ngini = 0.085\nsamples = 45\nvalue = [43, 2]\nclass = Died'),
#  Text(0.7049180327868853, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.7213114754098361, 0.29545454545454547, 'pclass <= 2.5\ngini = 0.044\nsamples = 44\nvalue = [43, 1]\nclass = Died'),
#  Text(0.7131147540983607, 0.25, 'age <= 27.5\ngini = 0.091\nsamples = 21\nvalue = [20, 1]\nclass = Died'),
#  Text(0.7049180327868853, 0.20454545454545456, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = Died'),
#  Text(0.7213114754098361, 0.20454545454545456, 'age <= 28.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]\nclass = Died'),
#  Text(0.7131147540983607, 0.1590909090909091, 'fare <= 13.25\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Died'),
#  Text(0.7049180327868853, 0.11363636363636363, 'fare <= 11.75\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.6967213114754098, 0.06818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.7131147540983607, 0.06818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.7213114754098361, 0.11363636363636363, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.7295081967213115, 0.1590909090909091, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Died'),
#  Text(0.7295081967213115, 0.25, 'gini = 0.0\nsamples = 23\nvalue = [23, 0]\nclass = Died'),
#  Text(0.7131147540983607, 0.4772727272727273, 'pclass <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.7049180327868853, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.7213114754098361, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.7540983606557377, 0.6136363636363636, 'fare <= 20.925\ngini = 0.494\nsamples = 9\nvalue = [5, 4]\nclass = Died'),
#  Text(0.7459016393442623, 0.5681818181818182, 'fare <= 8.206\ngini = 0.469\nsamples = 8\nvalue = [5, 3]\nclass = Died'),
#  Text(0.7377049180327869, 0.5227272727272727, 'embarked <= 1.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = Died'),
#  Text(0.7295081967213115, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.7459016393442623, 0.4772727272727273, 'fare <= 7.875\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Survived'),
#  Text(0.7377049180327869, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.7540983606557377, 0.4318181818181818, 'fare <= 7.91\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Died'),
#  Text(0.7459016393442623, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.7622950819672131, 0.38636363636363635, 'fare <= 7.988\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.7540983606557377, 0.3409090909090909, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.7704918032786885, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.7540983606557377, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.7622950819672131, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.8360655737704918, 0.6590909090909091, 'age <= 61.0\ngini = 0.117\nsamples = 80\nvalue = [75, 5]\nclass = Died'),
#  Text(0.819672131147541, 0.6136363636363636, 'fare <= 13.25\ngini = 0.1\nsamples = 76\nvalue = [72, 4]\nclass = Died'),
#  Text(0.8114754098360656, 0.5681818181818182, 'fare <= 12.762\ngini = 0.145\nsamples = 51\nvalue = [47, 4]\nclass = Died'),
#  Text(0.7868852459016393, 0.5227272727272727, 'fare <= 7.91\ngini = 0.089\nsamples = 43\nvalue = [41, 2]\nclass = Died'),
#  Text(0.7786885245901639, 0.4772727272727273, 'gini = 0.0\nsamples = 23\nvalue = [23, 0]\nclass = Died'),
#  Text(0.7950819672131147, 0.4772727272727273, 'fare <= 7.988\ngini = 0.18\nsamples = 20\nvalue = [18, 2]\nclass = Died'),
#  Text(0.7868852459016393, 0.4318181818181818, 'age <= 38.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Died'),
#  Text(0.7786885245901639, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.7950819672131147, 0.38636363636363635, 'age <= 41.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.7868852459016393, 0.3409090909090909, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.8032786885245902, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.8032786885245902, 0.4318181818181818, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]\nclass = Died'),
#  Text(0.8360655737704918, 0.5227272727272727, 'age <= 45.0\ngini = 0.375\nsamples = 8\nvalue = [6, 2]\nclass = Died'),
#  Text(0.8278688524590164, 0.4772727272727273, 'age <= 36.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Died'),
#  Text(0.819672131147541, 0.4318181818181818, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.8360655737704918, 0.4318181818181818, 'age <= 40.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.8278688524590164, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.8442622950819673, 0.38636363636363635, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.8442622950819673, 0.4772727272727273, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.8278688524590164, 0.5681818181818182, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]\nclass = Died'),
#  Text(0.8524590163934426, 0.6136363636363636, 'age <= 66.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Died'),
#  Text(0.8442622950819673, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.860655737704918, 0.5681818181818182, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died'),
#  Text(0.490874743852459, 0.7954545454545454, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.9200819672131147, 0.8409090909090909, 'fare <= 59.087\ngini = 0.466\nsamples = 46\nvalue = [29, 17]\nclass = Died'),
#  Text(0.8852459016393442, 0.7954545454545454, 'age <= 22.0\ngini = 0.444\nsamples = 12\nvalue = [4, 8]\nclass = Survived'),
#  Text(0.8770491803278688, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.8934426229508197, 0.75, 'age <= 43.5\ngini = 0.397\nsamples = 11\nvalue = [3, 8]\nclass = Survived'),
#  Text(0.8852459016393442, 0.7045454545454546, 'pclass <= 2.0\ngini = 0.32\nsamples = 10\nvalue = [2, 8]\nclass = Survived'),
#  Text(0.8770491803278688, 0.6590909090909091, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Survived'),
#  Text(0.8934426229508197, 0.6590909090909091, 'age <= 30.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = Survived'),
#  Text(0.8852459016393442, 0.6136363636363636, 'age <= 27.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Died'),
#  Text(0.8770491803278688, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.8934426229508197, 0.5681818181818182, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.9016393442622951, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.9016393442622951, 0.7045454545454546, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.9549180327868853, 0.7954545454545454, 'embarked <= 0.5\ngini = 0.389\nsamples = 34\nvalue = [25, 9]\nclass = Died'),
#  Text(0.9344262295081968, 0.75, 'fare <= 77.965\ngini = 0.49\nsamples = 14\nvalue = [6, 8]\nclass = Survived'),
#  Text(0.9262295081967213, 0.7045454545454546, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.9426229508196722, 0.7045454545454546, 'fare <= 369.927\ngini = 0.5\nsamples = 12\nvalue = [6, 6]\nclass = Died'),
#  Text(0.9344262295081968, 0.6590909090909091, 'fare <= 99.99\ngini = 0.48\nsamples = 10\nvalue = [6, 4]\nclass = Died'),
#  Text(0.9180327868852459, 0.6136363636363636, 'fare <= 85.638\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Survived'),
#  Text(0.9098360655737705, 0.5681818181818182, 'age <= 53.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.9016393442622951, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Died'),
#  Text(0.9180327868852459, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.9262295081967213, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.9508196721311475, 0.6136363636363636, 'age <= 17.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Died'),
#  Text(0.9426229508196722, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.9590163934426229, 0.5681818181818182, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Died'),
#  Text(0.9508196721311475, 0.6590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.9754098360655737, 0.75, 'fare <= 86.737\ngini = 0.095\nsamples = 20\nvalue = [19, 1]\nclass = Died'),
#  Text(0.9672131147540983, 0.7045454545454546, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]\nclass = Died'),
#  Text(0.9836065573770492, 0.7045454545454546, 'fare <= 121.731\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Died'),
#  Text(0.9754098360655737, 0.6590909090909091, 'embarked <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.9672131147540983, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.9836065573770492, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.9918032786885246, 0.6590909090909091, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Died')]

# %%
### Random Forest (classification)
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
     n_estimators = 201,
     oob_score=True
)
rf.fit(X_train,Y_train)
# Out:
# d:\AIML Prime\.venv\Lib\site-packages\sklearn\base.py:1336: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(n_estimators=201, oob_score=True)

# %%
y_pred = rf.predict(X_test)
print("OOB Score:",rf.oob_score_)
print("Testing Accuracy: ",accuracy_score(Y_test,y_pred))
# Out:
# OOB Score: 0.8105939004815409
# Testing Accuracy:  0.7761194029850746

# %%
## Decision Tree Model 
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(max_depth=4)
model.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
from sklearn.metrics import accuracy_score
y_pred_test = model.predict(X_test)
y_pred_train = model.predict(X_train)

## Evaluation
print("Training Accuracy:",accuracy_score(Y_train,y_pred_train)*100,"%")
print("Testing Accuracy:",accuracy_score(Y_test,y_pred_test)*100,"%")
# Out:
# Training Accuracy: 84.75120385232745 %
# Testing Accuracy: 82.46268656716418 %

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(18,10))
plot_tree(
     model,
     feature_names=X.columns,
     class_names = ["Died","Survived"],
     filled=True,
)
# Out:
# [Text(0.5089285714285714, 0.9, 'sex <= 0.5\ngini = 0.467\nsamples = 623\nvalue = [392, 231]\nclass = Died'),
#  Text(0.2857142857142857, 0.7, 'pclass <= 2.5\ngini = 0.396\nsamples = 213\nvalue = [58, 155]\nclass = Survived'),
#  Text(0.39732142857142855, 0.8, 'True  '),
#  Text(0.14285714285714285, 0.5, 'age <= 2.5\ngini = 0.07\nsamples = 110\nvalue = [4, 106]\nclass = Survived'),
#  Text(0.07142857142857142, 0.3, 'pclass <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Died'),
#  Text(0.03571428571428571, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Died'),
#  Text(0.10714285714285714, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.21428571428571427, 0.3, 'fare <= 149.035\ngini = 0.054\nsamples = 108\nvalue = [3, 105]\nclass = Survived'),
#  Text(0.17857142857142858, 0.1, 'gini = 0.041\nsamples = 96\nvalue = [2, 94]\nclass = Survived'),
#  Text(0.25, 0.1, 'gini = 0.153\nsamples = 12\nvalue = [1, 11]\nclass = Survived'),
#  Text(0.42857142857142855, 0.5, 'fare <= 23.35\ngini = 0.499\nsamples = 103\nvalue = [54, 49]\nclass = Died'),
#  Text(0.35714285714285715, 0.3, 'age <= 36.5\ngini = 0.492\nsamples = 85\nvalue = [37, 48]\nclass = Survived'),
#  Text(0.32142857142857145, 0.1, 'gini = 0.483\nsamples = 81\nvalue = [33, 48]\nclass = Survived'),
#  Text(0.39285714285714285, 0.1, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Died'),
#  Text(0.5, 0.3, 'age <= 7.0\ngini = 0.105\nsamples = 18\nvalue = [17, 1]\nclass = Died'),
#  Text(0.4642857142857143, 0.1, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Died'),
#  Text(0.5357142857142857, 0.1, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]\nclass = Died'),
#  Text(0.7321428571428571, 0.7, 'age <= 6.5\ngini = 0.302\nsamples = 410\nvalue = [334, 76]\nclass = Died'),
#  Text(0.6205357142857142, 0.8, '  False'),
#  Text(0.6071428571428571, 0.5, 'fare <= 27.562\ngini = 0.42\nsamples = 20\nvalue = [6, 14]\nclass = Survived'),
#  Text(0.5714285714285714, 0.3, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = Survived'),
#  Text(0.6428571428571429, 0.3, 'pclass <= 2.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4]\nclass = Died'),
#  Text(0.6071428571428571, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Survived'),
#  Text(0.6785714285714286, 0.1, 'gini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = Died'),
#  Text(0.8571428571428571, 0.5, 'fare <= 52.277\ngini = 0.267\nsamples = 390\nvalue = [328.0, 62.0]\nclass = Died'),
#  Text(0.7857142857142857, 0.3, 'age <= 77.0\ngini = 0.227\nsamples = 344\nvalue = [299, 45]\nclass = Died'),
#  Text(0.75, 0.1, 'gini = 0.224\nsamples = 343\nvalue = [299, 44]\nclass = Died'),
#  Text(0.8214285714285714, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.9285714285714286, 0.3, 'fare <= 59.087\ngini = 0.466\nsamples = 46\nvalue = [29, 17]\nclass = Died'),
#  Text(0.8928571428571429, 0.1, 'gini = 0.444\nsamples = 12\nvalue = [4, 8]\nclass = Survived'),
#  Text(0.9642857142857143, 0.1, 'gini = 0.389\nsamples = 34\nvalue = [25, 9]\nclass = Died')]
